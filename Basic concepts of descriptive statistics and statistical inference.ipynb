# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
file_path= r"C:\Users\Kevin\Downloads\housing.csv" # loading the dataset
data=pd.read_csv(file_path)
print(data.head())# displaying the first few rows of the dataset
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.shape #dimension of the dataset
# Out:
# (20640, 10)

# %%
data.info() #the data types of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.describe() #gives the general statistics of the dataset distributions without NAN Values
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.iloc[:-10]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20625    -121.52     39.12                37.0        102.0            17.0
# 20626    -121.43     39.18                36.0       1124.0           184.0
# 20627    -121.32     39.13                 5.0        358.0            65.0
# 20628    -121.48     39.10                19.0       2043.0           421.0
# 20629    -121.39     39.12                28.0      10035.0          1856.0
#
# ...

# %%
data.describe(include="all") #gives general overview of the dataset distribution including NAN values
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   20640.000000  20640.000000        20640.000000  20640.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.569704     35.631861           28.639486   2635.763081
# std         2.003532      2.135952           12.585558   2181.615252
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1447.750000
# 50%      -118.490000     34.260000           29.000000   2127.000000
# 75%      -118.010000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  39320.000000
#
#         total_bedrooms    population    households  median_income  \
# count     20433.000000  20640.000000  20640.000000   20640.000000
# ...

# %%
data.iloc[:,0] # first column
# Out:
# 0       -122.23
# 1       -122.22
# 2       -122.24
# 3       -122.25
# 4       -122.25
#           ...
# 20635   -121.09
# 20636   -121.21
# 20637   -121.22
# 20638   -121.32
# 20639   -121.24
# Name: longitude, Length: 20640, dtype: float64

# %%
data.describe()["latitude"].iloc[0] #the number of raws
# Out:
# np.float64(20640.0)

# %% [markdown]
# #### Question 1
# * Find the mean, median and mode population of the blocks
# * Find the most common total number of rooms in the block

# %%
round(data['population'].mean(),2)
# Out:
# np.float64(1425.48)

# %%
data['total_rooms'].mode()
# Out:
# 0    1527.0
# Name: total_rooms, dtype: float64

# %%
data['total_rooms'].median()
# Out:
# np.float64(2127.0)

# %%
data.count()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20433
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
print(f"Mean:{round(data['population'].mean(),2)}")
# Out:
# Mean:1425.48

# %%
# Out:
#   Cell In[30], line 1
#     print(f"The mode is:{data['total_rooms'].mode()}return f)
#           ^
# SyntaxError: unterminated f-string literal (detected at line 1)
